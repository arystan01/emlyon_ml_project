# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

from pathlib import Path

# %%
path_to_repo = Path('..').resolve()
path_to_data = path_to_repo / 'data'

# %%
df = pd.read_csv(path_to_data / 'final_clean_data.csv')

# %%
df
# Out:
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804            1             1                1             0
# 1      5008805            1             1                1             0
# 2      5008806            1             1                1             0
# 3      5008808            0             0                1             0
# 4      5008809            0             0                1             0
# ...        ...          ...           ...              ...           ...
# 36452  5149828            1             1                1             0
# 36453  5149834            0             0                1             0
# 36454  5149838            0             0                1             0
# 36455  5150049            0             0                1             0
# 36456  5150337            1             0                1             0
#
#        NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  \
# 0                     3                    1                   0
# 1                     3                    1                   0
# 2                     3                    4                   1
# 3                     0                    4                   3
# 4                     0                    4                   3
# ...                 ...                  ...                 ...
# 36452                 3                    4                   1
# 36453                 0                    1                   1
# 36454                 1                    1                   1
# 36455                 3                    4                   1
# 36456                 3                    4                   3
#
#        NAME_HOUSING_TYPE  FLAG_MOBIL  ...  EXPERIENCE_BIN  AGE_BIN  \
# 0                      4           1  ...               3        1
# 1                      4           1  ...               3        1
# 2                      1           1  ...               1        3
# 3                      1           1  ...               2        3
# 4                      1           1  ...               2        3
# ...                  ...         ...  ...             ...      ...
# 36452                  1           1  ...               2        2
# 36453                  1           1  ...               1        1
# 36454                  1           1  ...               1        1
# 36455                  1           1  ...               1        2
# 36456                  4           1  ...               1        1
#
#        AGE_X_LOG_INCOME  EXP_X_INCOME  HIGH_INCOME_FLAG  INCOME_BIN  ADULTS  \
# 0            414.902781    155.588543                 0           3       2
# 1            414.902781    155.588543                 0           3       2
# 2            674.581609     34.892152                 0           0       2
# 3            650.321409    100.049448                 0           3       1
# 4            650.321409    100.049448                 0           3       1
# ...                 ...           ...               ...         ...     ...
# 36452        595.035561     75.961987                 0           3       2
# 36453        394.917174     35.901561                 0           1       2
# 36454        394.917174     35.901561                 0           1       2
# 36455        615.193576     12.554971                 0           3       2
# 36456        290.767935     34.892152                 0           0       1
#
#        EXP_AGE_RATIO  STABILITY_SCORE  CHILD_BIN
# 0           0.375000              2.1        NaN
# 1           0.375000              2.1        NaN
# 2           0.051724              0.7        NaN
# 3           0.153846              1.1        NaN
# 4           0.153846              1.1        NaN
# ...              ...              ...        ...
# 36452       0.127660              1.4        NaN
# 36453       0.090909              1.3        NaN
# 36454       0.090909              1.3        NaN
# 36455       0.020408              1.0        NaN
# 36456       0.120000              1.3        NaN
#
# [36457 rows x 30 columns]

# %%
y = df["bad"]
X = df.drop(columns=["bad", "ID"])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

print("Train target distribution:")
print(y_train.value_counts())

print("\nTest target distribution:")
print(y_test.value_counts())
# Out:
# Train target distribution:
# bad
# 0    28672
# 1      493
# Name: count, dtype: int64
#
# Test target distribution:
# bad
# 0    7169
# 1     123
# Name: count, dtype: int64
